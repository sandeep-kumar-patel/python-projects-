# %% [markdown]
# ## About Case Study
#
# Have you ever struggled to analyze big datasets in Excel then, you should have considered Pandas, powerful programming and data analysis toolbox which allows you to manipulate million-row data points in milliseconds with high processing power and user productivity.
#
# In this project, You will going to work with real dataset which is about marketing campaign. Targeted marketing, by definition, is the strategy of tailoring and personalizing online advertising according to data acquired on some intended audience.
#
# In other words, instead of sending out ads to an incredibly large audience, a subset is selected based on their traits, interests, and preferences.
#
# Dataset has fields like customers personal details like name, year of birth, martial status etc and also their recent purchase behaviour which includes last purchase_date, recency score, purchases so far etc

# %% [markdown]
# ## Problem Statement
#
# Analyze the given marketing campaign dataset to find interesting insights and relation among the user attributes which should lead to increase in the effectiveness of same. The analysis and takeaway will be consumed by marketing team to implement next marketing campaign.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Change the directory to folder where dataset is located
# %cd /content/drive/My Drive/PYTHON Rework/Week 3/Day 4
# %ls
# %pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1SKciv6INUduNL2UGc9ExcKu0d_AUZ0Jh/PYTHON Rework/Week 3/Day 4
#  customer_data.xlsx  'Old Data'/                 project_data.csv
#  edu_data.csv        'Pandas Case Study.ipynb'  'project_data (main).csv'
# '/content/drive/.shortcut-targets-by-id/1SKciv6INUduNL2UGc9ExcKu0d_AUZ0Jh/PYTHON Rework/Week 3/Day 4'

# %% [markdown]
# Loading the required libraries

# %%
import pandas as pd
import numpy as np
from datetime import date
import datetime as dt

# %% [markdown]
# Read the CSV data

# %%
## Read the data using pandas functions

dfp = pd.read_csv('project_data.csv')
dfe = pd.read_csv('edu_data.csv')
dfc_1 = pd.read_excel('customer_data.xlsx', sheet_name='Data 1')
dfc_2 = pd.read_excel('customer_data.xlsx', sheet_name='Data 2')

# %% [markdown]
# As we have two seperate files of customer_data. Let's concatenate them to make one.

# %%
## Concatenate or append both customer_data using concat function

dfc = pd.concat([dfc_1, dfc_2], ignore_index=True)

# %% [markdown]
# Let's go through each data table and skim through the fields

# %%
## Print the head of the project data

dfp.head(10)
# Out:
#    customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 0     20201701    09-04-2012       58                 8                4
# 1     20201702    03-08-2014       38                 1                2
# 2     20201703     8/21/2013       26                 8               10
# 3     20201704    02-10-2014       26                 2                4
# 4     20201705     1/19/2014       94                 5                6
# 5     20201706    09-09-2013       16                 6               10
# 6     20201707    11/13/2012       34                 7                7
# 7     20201708    05-08-2013       32                 4                4
# 8     20201709    06-06-2013       19                 3                2
# 9     20201710     3/13/2014       68                 1                0
#
#    complaints  calls  intercoms
# 0           0      3         11
# 1           0      3         11
# 2           0      3         11
# 3           0      3         11
# 4           0      3         11
# 5           5      3         11
# 6           0      3         11
# 7           0      3         11
# 8           3      3         11
# 9           5      3         11

# %%
## Print the head of the education data

dfe.head(10)
# Out:
#   educational_level educational_status_code
# 0        Graduation                      GD
# 1               PhD                      PH
# 2            Master                      MS
# 3             Basic                      BS
# 4       High School                      HS

# %%
## Print the head of the customer data

dfc.head(10)
# Out:
#       cust_id  year_of_birth educational_status_code marital_status  \
# 0  20201733.0         1940.0                      GD        Married
# 1  20202059.0         1943.0                     NaN        Married
# 2  20202195.0         1944.0                      PH       Divorced
# 3  20201983.0         1946.0                      GD   Relationship
# 4  20202060.0         1948.0                      PH       Divorced
# 5  20201723.0         1949.0                      PH        Widowed
# 6  20201990.0         1949.0                      MS       Divorced
# 7  20202199.0         1949.0                      PH   Relationship
# 8  20201702.0         1950.0                      GD        Married
# 9  20201725.0         1951.0                      GD       Divorced
#
#    annual_income              full_name
# 0        40548.0            Abhinav Bal
# 1        65073.0            Nimai Neela
# 2        55614.0         Somatra Savant
# 3        46276.0            Kamana Nath
# 4        46681.0  Ninarika Chandrasekar
# 5        58607.0          Naveen Badami
# 6        35416.0          Kapila Kapoor
# 7        41461.0           Sthir Sehgal
# 8        46344.0       Advitiya Agarwal
# 9        40689.0            Aarav Bahri

# %% [markdown]
# Let's find out the size of the each data table.

# %%
## Print the shape all data table

dfp.shape
# Out:
# (499, 8)

# %%
dfe.shape
# Out:
# (5, 2)

# %%
dfc.shape
# Out:
# (391, 6)

# %%
## Print the info of all data tables

dfp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       499 non-null    int64
#  1   purhcase_date     499 non-null    object
#  2   recency           499 non-null    int64
#  3   online_purchases  499 non-null    int64
#  4   store_purchases   499 non-null    int64
#  5   complaints        499 non-null    int64
#  6   calls             499 non-null    int64
#  7   intercoms         499 non-null    int64
# dtypes: int64(7), object(1)
# memory usage: 31.3+ KB

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   cust_id                  391 non-null    float64
#  1   year_of_birth            391 non-null    float64
#  2   educational_status_code  363 non-null    object
#  3   marital_status           391 non-null    object
#  4   annual_income            373 non-null    float64
#  5   full_name                391 non-null    object
# dtypes: float64(3), object(3)
# memory usage: 18.5+ KB

# %% [markdown]
# Another interesting method is data.info() which gives us the number of data points and variables of the dataset. It also displays the data types. We can see that our dataset has 499 data points and 12 variables ranging from customers’ personal information to purchases, calls, intercoms, and complaints.

# %% [markdown]
# Let's perform a high level descriptive analysis using pandas describe method.

# %%
## Get the high level analysis done using describe function

dfp.describe()
# Out:
#         customer_id     recency  online_purchases  store_purchases  \
# count  4.990000e+02  499.000000        499.000000       499.000000
# mean   2.020195e+07   48.228457          3.969940         5.779559
# std    1.441932e+02   29.077101          2.813675         3.301378
# min    2.020170e+07    0.000000          0.000000         0.000000
# 25%    2.020183e+07   23.000000          2.000000         3.000000
# 50%    2.020195e+07   47.000000          3.000000         5.000000
# 75%    2.020207e+07   74.000000          6.000000         8.000000
# max    2.020220e+07   99.000000         27.000000        13.000000
#
#        complaints       calls   intercoms
# count  499.000000  499.000000  499.000000
# mean     0.252505    3.370741   10.168337
# std      1.115953    4.327091    2.800552
# min      0.000000    0.000000    2.000000
# 25%      0.000000    3.000000   11.000000
# 50%      0.000000    3.000000   11.000000
# 75%      0.000000    3.000000   11.000000
# max     11.000000   88.000000   44.000000

# %% [markdown]
# ##### Descriptive Statistics
# \#1 <br>
# The **recency** factor is based on the notion that the more recently a customer has made a purchase with a company, the more likely they will continue to keep the business and brand in mind for subsequent purchases.
#
# As minimum recency score is 0 and maximum 99, data looks evening distributed as 25% of the data has recency of 23, 50% of the data has recency of 47 etc. Also, As mean (i.e average) is close to median.
#
# \#2 <br>
# Analysing purchase pattern, even though maximum puchase volume is 27 it looks like customer's aren't making much online purchase as 75% of distribution is till online purchase of volume 6

# %%
## Analyzing customer_data
dfc.describe(include="all")

## All values in project_data is numeric hence no point of using include="all"
# Out:
#              cust_id  year_of_birth educational_status_code marital_status  \
# count   3.910000e+02     391.000000                     363            391
# unique           NaN            NaN                       5              6
# top              NaN            NaN                      GD        Married
# freq             NaN            NaN                     195             94
# mean    2.020195e+07    1978.621483                     NaN            NaN
# std     1.461739e+02      13.844927                     NaN            NaN
# min     2.020170e+07    1940.000000                     NaN            NaN
# 25%     2.020182e+07    1970.000000                     NaN            NaN
# 50%     2.020195e+07    1982.000000                     NaN            NaN
# 75%     2.020208e+07    1989.000000                     NaN            NaN
# max     2.020220e+07    2000.000000                     NaN            NaN
#
#         annual_income    full_name
# count      373.000000          391
# unique            NaN          391
# top               NaN  Abhinav Bal
# freq              NaN            1
# mean     51113.949062          NaN
# std      21152.035692          NaN
# min       2447.000000          NaN
# 25%      34554.000000          NaN
# 50%      50520.000000          NaN
# 75%      68491.000000          NaN
# max     102692.000000          NaN

# %% [markdown]
# ##### Descriptive Statistics
# \#1 <br>
# Year of Birth should not be considered as numerical as its mean of 1978.36 doesn't make sense. So we can safely ignore it.
#
# \#2 <br>
# Most of the customer we have has status Married.

# %%
## Check if any table has a missing value using isnull and sum function

dfp.isnull().sum()
# Out:
# customer_id         0
# purhcase_date       0
# recency             0
# online_purchases    0
# store_purchases     0
# complaints          0
# calls               0
# intercoms           0
# dtype: int64

# %%
dfc.isnull().sum()
# Out:
# cust_id                     0
# year_of_birth               0
# educational_status_code    28
# marital_status              0
# annual_income              18
# full_name                   0
# dtype: int64

# %%
## Print the data where annual_income is missing

dfc[dfc["annual_income"].isnull()]
# Out:
#         cust_id  year_of_birth educational_status_code marital_status  \
# 10   20201749.0         1951.0                      GD        Married
# 33   20201791.0         1957.0                      PH   Relationship
# 34   20201792.0         1957.0                      GD        Married
# 49   20202157.0         1957.0                      HS         Single
# 56   20201744.0         1959.0                      PH       Divorced
# 59   20201829.0         1961.0                      PH        Married
# 130  20201793.0         1973.0                      MS   Relationship
# 143  20201985.0         1975.0                      MS        Married
# 171  20201834.0         1980.0                      GD   Relationship
# 197  20201759.0         1982.0                      GD   Relationship
# 211  20202005.0         1982.0                      GD   Relationship
# 217  20201711.0         1983.0                      GD         Single
# 259  20202105.0         1986.0                      PH       Divorced
# 275  20201874.0         1988.0                      PH        Married
# 283  20201772.0         1988.0                      HS         Single
# 304  20202013.0         1990.0                      GD         Single
# 342  20201779.0         1995.0                      HS   Relationship
# 362  20202020.0         1997.0                      GD       Divorced
#
#      annual_income            full_name
# 10             NaN         Adrika Bandi
# 33             NaN         Ananya Bhatt
# 34             NaN  Anaya Bhattacharyya
# 49             NaN         Ramesh Saini
# 56             NaN          Adita Balan
# 59             NaN      Dharinija Chana
# 130            NaN        Svara Shankar
# 143            NaN            Kami Goel
# 171            NaN       Dhruv Chandran
# 197            NaN      Akanksha Barman
# 211            NaN         Mayank Raman
# 217            NaN        Avidosa Amble
# 259            NaN           Pavan Raja
# 275            NaN         Gayatri Toor
# 283            NaN         Tanuja Sibal
# 304            NaN        Minda Narayan
# 342            NaN         Amrit Bhalla
# 362            NaN            Mojil Roy

# %% [markdown]
# We know that in customer_data has missing annual income of the customer. Let's try to impute them. Although we can simply take average of all the customer's salary but we should not do that as different classes might have different salary for various reasons. For example a single individual might have less salary compared to married working couple. Hence let's take average salary based on the category and replace missing values.

# %%
## Check what all martial status available

dfc['marital_status'].unique()
# Out:
# array(['Married', 'Divorced', 'Relationship', 'Widowed', 'Single',
#        'Widow'], dtype=object)

# %% [markdown]
# Let us consider we are interested to know the unique values of the marital status field then, we should select the column and apply the unique method. As shown below the variable marital status has 5 unique categories. However, we notice that widow and widowed are two two different naming for the same category so we can make it consistent through using replace method on the column values as displayed below.

# %%
## Replace one of the status using string's replace function

dfc['marital_status'] = dfc['marital_status'].replace('Widow', 'Widowed')

# %%
## Check martial status again

dfc['marital_status'].unique()
# Out:
# array(['Married', 'Divorced', 'Relationship', 'Widowed', 'Single'],
#       dtype=object)

# %%
## Find out the average salary based on each martial_status.
## Additionally, reset the index to convert into Df

annual_income_avg = dfc.groupby("marital_status")["annual_income"].mean().reset_index()

# %%
## Write an function to replace missing annual income value with its average (based on martial status)

def annual_income_avg_def (annual_income, marital_status) :
  if pd.isna(annual_income) :         ## Important Condition
    return float(annual_income_avg[annual_income_avg['marital_status'] == marital_status]['annual_income'])
  return annual_income

# Function Testing
# annual_income_avg_def(None, "Single")

# %%
## Run through each row using apply and lambda to replace the value

dfc['annual_income'] = dfc.apply(lambda x: annual_income_avg_def(x["annual_income"], x["marital_status"]), axis=1) ## It is important to apply axis=1 othetwise this code will throw KeyError

# %%
## Alternative approach using group by + apply + lambda

dfc.groupby('marital_status').apply(lambda g: g['annual_income'].fillna(g['annual_income'].mean()))
# Out:
# marital_status
# Divorced        2       55614.0
#                 4       46681.0
#                 6       35416.0
#                 9       40689.0
#                 13      73448.0
#                          ...
# Widowed         356     36143.0
#                 361    102692.0
#                 374     19789.0
#                 380     34421.0
#                 385     34176.0
# Name: annual_income, Length: 391, dtype: float64

# %%
## Checking annual_income column for null values
dfc['annual_income'].isnull().sum()
# Out:
# 0

# %%
dfc.isnull().sum()
# Out:
# cust_id                     0
# year_of_birth               0
# educational_status_code    28
# marital_status              0
# annual_income               0
# full_name                   0
# dtype: int64

# %% [markdown]
# As we need to do thorough analysis we will get to get data from various tables possible. Hence let's merge them based on primary keys.

# %%
## Left join Project and Customer table using merge function
## Make sure to keep project_data as left table and customer_data as right table
## So that with left join we don't lose the missing customer data information
## Save it in the temporary DF as we need to join one more table

df_temp = pd.merge(dfp, dfc, left_on='customer_id', right_on='cust_id', how='left')
df_temp
# Out:
#      customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 0       20201701    09-04-2012       58                 8                4
# 1       20201702    03-08-2014       38                 1                2
# 2       20201703     8/21/2013       26                 8               10
# 3       20201704    02-10-2014       26                 2                4
# 4       20201705     1/19/2014       94                 5                6
# ..           ...           ...      ...               ...              ...
# 495     20202195    11/27/2013       85                 9                6
# 496     20202196     4/13/2013       88                 5               11
# 497     20202197    04-05-2014       22                 2                3
# 498     20202198     4/21/2013       83                 4                4
# 499     20202199     5/22/2014       63                 6               11
#
#      complaints  calls  intercoms     cust_id  year_of_birth  \
# 0             0      3         11  20201701.0         1982.0
# 1             0      3         11  20201702.0         1950.0
# 2             0      3         11  20201703.0         1965.0
# 3             0      3         11         NaN            NaN
# 4             0      3         11  20201705.0         1981.0
# ..          ...    ...        ...         ...            ...
# 495           0      3         11  20202195.0         1944.0
# 496           0      3         11  20202196.0         1962.0
# 497           0      3         11  20202197.0         1978.0
# 498           0      6         11  20202198.0         1971.0
# 499           0      6         11  20202199.0         1949.0
#
#     educational_status_code marital_status  annual_income         full_name
# 0                        GD         Single        58138.0     Aditi Acharya
# 1                        GD        Married        46344.0  Advitiya Agarwal
# 2                        GD       Divorced        71613.0    Alagesan Agate
# 3                       NaN            NaN            NaN               NaN
# 4                        PH        Widowed        58293.0   Amrish Aggarwal
# ..                      ...            ...            ...               ...
# 495                      PH       Divorced        55614.0    Somatra Savant
# 496                      MS       Divorced        59432.0      Sona Sawhney
# 497                      GD       Divorced        55563.0      Tamal Shenoy
# 498                      PH   Relationship        43624.0     Souvik Saxena
# 499                      PH   Relationship        41461.0      Sthir Sehgal
#
# [500 rows x 14 columns]

# %%
## Join temporary joined table with education data table

df = pd.merge(df_temp, dfe, left_on='educational_status_code', right_on='educational_status_code', how='left')
df
# Out:
#      customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 0       20201701    09-04-2012       58                 8                4
# 1       20201702    03-08-2014       38                 1                2
# 2       20201703     8/21/2013       26                 8               10
# 3       20201704    02-10-2014       26                 2                4
# 4       20201705     1/19/2014       94                 5                6
# ..           ...           ...      ...               ...              ...
# 495     20202195    11/27/2013       85                 9                6
# 496     20202196     4/13/2013       88                 5               11
# 497     20202197    04-05-2014       22                 2                3
# 498     20202198     4/21/2013       83                 4                4
# 499     20202199     5/22/2014       63                 6               11
#
#      complaints  calls  intercoms     cust_id  year_of_birth  \
# 0             0      3         11  20201701.0         1982.0
# 1             0      3         11  20201702.0         1950.0
# 2             0      3         11  20201703.0         1965.0
# 3             0      3         11         NaN            NaN
# 4             0      3         11  20201705.0         1981.0
# ..          ...    ...        ...         ...            ...
# 495           0      3         11  20202195.0         1944.0
# 496           0      3         11  20202196.0         1962.0
# 497           0      3         11  20202197.0         1978.0
# 498           0      6         11  20202198.0         1971.0
# 499           0      6         11  20202199.0         1949.0
#
#     educational_status_code marital_status  annual_income         full_name  \
# 0                        GD         Single        58138.0     Aditi Acharya
# 1                        GD        Married        46344.0  Advitiya Agarwal
# 2                        GD       Divorced        71613.0    Alagesan Agate
# 3                       NaN            NaN            NaN               NaN
# 4                        PH        Widowed        58293.0   Amrish Aggarwal
# ..                      ...            ...            ...               ...
# 495                      PH       Divorced        55614.0    Somatra Savant
# 496                      MS       Divorced        59432.0      Sona Sawhney
# 497                      GD       Divorced        55563.0      Tamal Shenoy
# 498                      PH   Relationship        43624.0     Souvik Saxena
# 499                      PH   Relationship        41461.0      Sthir Sehgal
#
#     educational_level
# 0          Graduation
# 1          Graduation
# 2          Graduation
# 3                 NaN
# 4                 PhD
# ..                ...
# 495               PhD
# 496            Master
# 497        Graduation
# 498               PhD
# 499               PhD
#
# [500 rows x 15 columns]

# %% [markdown]
# Do we have any missing data? <br>
#
# Let's check.

# %%
df.isnull().sum()
# Out:
# customer_id                  0
# purhcase_date                0
# recency                      0
# online_purchases             0
# store_purchases              0
# complaints                   0
# calls                        0
# intercoms                    0
# cust_id                    109
# year_of_birth              109
# educational_status_code    137
# marital_status             109
# annual_income              109
# full_name                  109
# educational_level          137
# dtype: int64

# %% [markdown]
# It looks like we don't have customer information of 109 customers as we see 109 cust_id missing in compare to customer_id.
#
# > Task - Try joining the table with inner join.

# %% [markdown]
# What is the highest education level of the customer?

# %%
## Filter the educational level and find the number of records for each
## Additionally sort the value in descending order

round(df['educational_level'].value_counts(),2).sort_values(ascending=False)
# Out:
# Graduation     195
# PhD             80
# Master          54
# High School     28
# Basic            6
# Name: educational_level, dtype: int64

# %% [markdown]
# Print only customer details of the customer and save it in different DataFrame.
#
# DataFrame should contain `'full_name','year_of_birth', 'educational_level', 'annual_income'` columns.

# %%
## Create an derived table from main table as per the columns mentioned above

edu_details = df[['full_name','year_of_birth', 'educational_level', 'annual_income']]
edu_details
# Out:
#             full_name  year_of_birth educational_level  annual_income
# 0       Aditi Acharya         1982.0        Graduation        58138.0
# 1    Advitiya Agarwal         1950.0        Graduation        46344.0
# 2      Alagesan Agate         1965.0        Graduation        71613.0
# 3                 NaN            NaN               NaN            NaN
# 4     Amrish Aggarwal         1981.0               PhD        58293.0
# ..                ...            ...               ...            ...
# 495    Somatra Savant         1944.0               PhD        55614.0
# 496      Sona Sawhney         1962.0            Master        59432.0
# 497      Tamal Shenoy         1978.0        Graduation        55563.0
# 498     Souvik Saxena         1971.0               PhD        43624.0
# 499      Sthir Sehgal         1949.0               PhD        41461.0
#
# [500 rows x 4 columns]

# %% [markdown]
# Display those customers who have done Masters.

# %%
df[df["educational_level"] == "Master"]
# Out:
#      customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 5       20201706    09-09-2013       16                 6               10
# 13      20201714    11/15/2013       53                 6                5
# 18      20201719     3/28/2013       91                11                9
# 30      20201731     5/22/2014       34                 3                3
# 34      20201735     2/20/2013        4                 3                9
# 44      20201745    10-02-2013       19                 2                3
# 51      20201752    08-11-2012        2                 6               13
# 60      20201761    07-04-2013       12                 3               11
# 70      20201771    09-11-2012        1                 4                6
# 76      20201777     8/27/2012       34                 7                5
# 86      20201787     7/16/2013       48                 3                4
# 92      20201793    11/23/2013       87                 2                8
# 93      20201794     3/23/2014       69                 1                3
# 120     20201821     6/20/2013       65                 6               10
# 122     20201823    09-04-2013       63                 1                3
# 127     20201828    06-08-2014       51                 2                4
# 131     20201832    03-10-2013       42                11                6
# 140     20201841    10/19/2012       46                 5               12
# 149     20201850     6/21/2014       65                 2                4
# 196     20201897     5/13/2014       80                 7               12
# 205     20201906    11-10-2012        5                 0                2
# 213     20201914     1/21/2013       21                 7                8
# 217     20201918    11/15/2013       81                 8                6
# 236     20201937    12-04-2013       46                 1                3
# 249     20201950    10/29/2012       57                 9                6
# 262     20201963     6/17/2014       85                 4                6
# 265     20201966     3/14/2013       30                 3                3
# 284     20201985     4/17/2014       18                 2                3
# 287     20201988    01-08-2013       88                 6               12
# 289     20201990     6/13/2013       62                 7                5
# 295     20201996     8/23/2012       62                 3               11
# 297     20201998     1/13/2013       43                 3                3
# 309     20202010     4/27/2013       12                 4                4
# 313     20202014    02-06-2013       42                 6               10
# 372     20202073     8/29/2013       52                 1                2
# 375     20202076     8/18/2012       86                 3                2
# 384     20202085     3/30/2014       33                 0                2
# 386     20202087    10/16/2013       11                 7                4
# 391     20202092    12-09-2013        0                 3                6
# 394     20202095     2/25/2014       80                 5               12
# 420     20202120    03-05-2013        4                10                8
# 423     20202123    06-05-2014       75                 1                2
# 424     20202124    06-04-2013       26                 3                8
# 436     20202136     6/21/2013       49                 1                3
# 438     20202138    09-07-2013       14                 9                5
# 447     20202147    10-09-2013       92                 5                4
# 453     20202153    10/17/2013       17                 2                4
# 458     20202158    04-01-2013       71                 4                5
# 478     20202178     5/23/2014       19                 7                8
# 481     20202181    12/30/2013       60                 2                2
# 482     20202182    08-11-2013       54                 2                3
# 487     20202187    11/14/2013        4                 3                7
# 494     20202194    01-12-2013       77                 2                3
# 496     20202196     4/13/2013       88                 5               11
#
#      complaints  calls  intercoms     cust_id  year_of_birth  \
# 5             5      3         11  20201706.0         1967.0
# 13            0      3         11  20201714.0         1952.0
# 18            4      3         11  20201719.0         1980.0
# 30            8      3         11  20201731.0         1989.0
# 34            5      3         11  20201735.0         1975.0
# 44            0      3         11  20201745.0         1975.0
# 51            0      3         11  20201752.0         1964.0
# 60            0      3         11  20201761.0         1982.0
# 70            0      3         11  20201771.0         1987.0
# 76            0      3         11  20201777.0         1993.0
# 86            0      3         11  20201787.0         1970.0
# 92            0      3          7  20201793.0         1973.0
# 93            0      3          7  20201794.0         1982.0
# 120           0      5         11  20201821.0         1957.0
# 122           0      3          3  20201823.0         1967.0
# 127           0      3         11  20201828.0         1953.0
# 131           0      3         11  20201832.0         1975.0
# 140           0      3          2  20201841.0         1987.0
# 149           0      3          5  20201850.0         1996.0
# 196           0      3         11  20201897.0         1982.0
# 205           0      3         11  20201906.0         1991.0
# 213           0      8         11  20201914.0         1981.0
# 217           0      3         11  20201918.0         1985.0
# 236           0      3         11  20201937.0         1981.0
# 249           0      3         11  20201950.0         1994.0
# 262           0      3         11  20201963.0         1957.0
# 265           0      3         11  20201966.0         1966.0
# 284           0      3         11  20201985.0         1975.0
# 287           0      3         11  20201988.0         1956.0
# 289           0      3         11  20201990.0         1949.0
# 295           0      3         11  20201996.0         1952.0
# 297           0      3         11  20201998.0         1986.0
# 309           0      3         11  20202010.0         1987.0
# 313           0      3         11  20202014.0         1991.0
# 372           0      3         11  20202073.0         1984.0
# 375           0      3         11  20202076.0         1987.0
# 384           0      3         11  20202085.0         1996.0
# 386           0      3         11  20202087.0         1998.0
# 391           0      3         11  20202092.0         1970.0
# 394           0      3         11  20202095.0         1967.0
# 420           0      3         11  20202120.0         1990.0
# 423           0      3         11  20202123.0         1957.0
# 424           0      3         11  20202124.0         1973.0
# 436           0      0         11  20202136.0         1983.0
# 438           0      3         11  20202138.0         1985.0
# 447           0      3         11  20202147.0         1994.0
# 453           0      3         11  20202153.0         2000.0
# 458           0      3         11  20202158.0         1973.0
# 478           0      3         11  20202178.0         1977.0
# 481           0      3         11  20202181.0         1973.0
# 482           0      3         11  20202182.0         1972.0
# 487           0     11         11  20202187.0         1976.0
# 494           0      3         11  20202194.0         1964.0
# 496           0      3         11  20202196.0         1962.0
#
#     educational_status_code marital_status  annual_income  \
# 5                        MS   Relationship   62000.000000
# 13                       MS         Single   59354.000000
# 18                       MS         Single   76995.000000
# 30                       MS       Divorced   10979.000000
# 34                       MS        Married   68657.000000
# 44                       MS   Relationship    7500.000000
# 51                       MS         Single   79143.000000
# 60                       MS         Single   75777.000000
# 70                       MS         Single   66991.000000
# 76                       MS        Married   75251.000000
# 86                       MS   Relationship   36138.000000
# 92                       MS   Relationship   50609.129412
# 93                       MS         Single   42394.000000
# 120                      MS   Relationship   88193.000000
# 122                      MS        Married   19510.000000
# 127                      MS        Married   54348.000000
# 131                      MS        Married   61331.000000
# 140                      MS         Single   92859.000000
# 149                      MS         Single   49605.000000
# 196                      MS       Divorced   69661.000000
# 205                      MS   Relationship   18890.000000
# 213                      MS        Widowed   46014.000000
# 217                      MS        Widowed   83790.000000
# 236                      MS       Divorced   23661.000000
# 249                      MS        Married   65176.000000
# 262                      MS        Married   44159.000000
# 265                      MS        Widowed   38179.000000
# 284                      MS        Married   49201.921348
# 287                      MS         Single   50898.000000
# 289                      MS       Divorced   35416.000000
# 295                      MS       Divorced   55951.000000
# 297                      MS        Widowed   42386.000000
# 309                      MS        Widowed   42670.000000
# 313                      MS        Married   70893.000000
# 372                      MS        Married   29548.000000
# 375                      MS         Single   46098.000000
# 384                      MS        Widowed   36143.000000
# 386                      MS        Married   43795.000000
# 391                      MS       Divorced   62499.000000
# 394                      MS       Divorced   70777.000000
# 420                      MS   Relationship   49505.000000
# 423                      MS        Married   18492.000000
# 424                      MS   Relationship   82584.000000
# 436                      MS   Relationship   82634.000000
# 438                      MS        Widowed   51529.000000
# 447                      MS       Divorced   42618.000000
# 453                      MS         Single   36230.000000
# 458                      MS        Married   42207.000000
# 478                      MS        Married   55842.000000
# 481                      MS        Married   38961.000000
# 482                      MS       Divorced   37760.000000
# 487                      MS   Relationship   56290.000000
# 494                      MS         Single   58308.000000
# 496                      MS       Divorced   59432.000000
#
#                  full_name educational_level
# 5      Aprativirya Agrawal            Master
# 13           Tamanna Shere            Master
# 18           Hardeep Atwal            Master
# 30        Abhilasha Bakshi            Master
# 34            Abishek Bala            Master
# 44   Aditi Balasubramanian            Master
# 51            Agrata Banik            Master
# 60             Akhil Bassi            Master
# 70              Amare Bedi            Master
# 76           Amithi Bhagat            Master
# 86             Anandi Bhat            Master
# 92           Svara Shankar            Master
# 93             Anik Bhatti            Master
# 120             Deven Chad            Master
# 122           Devesh Chada            Master
# 127    Devisha Chakraborty            Master
# 131        Dhavala Chander            Master
# 140      Divya Subramaniam            Master
# 149           Ekavali Sura            Master
# 196       Harini Venkatesh            Master
# 205             Hira Kumar            Master
# 213              Indra Lal            Master
# 217            Ishan Lalla            Master
# 236         Jatin Malhotra            Master
# 249        Jinendra Mangal            Master
# 262             Kaavia Lal            Master
# 265               Kali Jai            Master
# 284              Kami Goel            Master
# 287           Kanika Anand            Master
# 289          Kapila Kapoor            Master
# 295        Kartik Malhotra            Master
# 297          Kash Engineer            Master
# 309             Mena Sethi            Master
# 313            Mita Mittal            Master
# 372         Nithanya Veena            Master
# 375            Nitya Manju            Master
# 384             Ojas Tyagi            Master
# 386     Omanand Srivastava            Master
# 391           Padma Neelam            Master
# 394            Sunil Setty            Master
# 420      Pravin Ramanathan            Master
# 423             Prema Rana            Master
# 424       Premala Randhawa            Master
# 436           Rachna Raval            Master
# 438            Radha Ravel            Master
# 447               Raja Roy            Master
# 453          Tejas Sridhar            Master
# 458          Ramesha Salvi            Master
# 478          Rhynisha Sant            Master
# 481            Ripam Saran            Master
# 482            Taia Sharma            Master
# 487         Rishika Sarkar            Master
# 494            Sohan Sathe            Master
# 496           Sona Sawhney            Master

# %% [markdown]
# Display the top 10 records of the customer based on their recency.
#
# Record should display `'full_name','educational_level', 'annual_income'` columns

# %%
## Display the top 10 records of the customer based on their recency using loc function
## Additionally sort them using sort_values function

df.loc[:, ['full_name','educational_level', 'annual_income']].sort_values(by='annual_income', ascending=False, na_position='last').head(10)
# Out:
#                full_name educational_level  annual_income
# 252            Jute Mani        Graduation       102692.0
# 203          Himani Vyas               PhD       102160.0
# 124          Devi Chadha        Graduation       101970.0
# 425    Prita Ranganathan               PhD        93027.0
# 140    Divya Subramaniam            Master        92859.0
# 419           Taru Soman        Graduation        91065.0
# 120           Deven Chad            Master        88193.0
# 198           Harsha Vig        Graduation        86718.0
# 407    Piroj Rajagopalan               PhD        86164.0
# 142  Divyesh Subramanian        Graduation        86111.0

# %% [markdown]
# Do the same using .iloc function

# %%
## Try the same with iloc for practice purpose. Although loc is more easy to use

## Since columns with iloc can only be accessed by column index we need to know the index number
print(list(df.columns).index('full_name'))
print(list(df.columns).index('educational_level'))
print(list(df.columns).index('annual_income'))
# Out:
# 13
# 14
# 12

# %%
df.iloc[:10, [13,14,12]].sort_values(by='annual_income', ascending=False, na_position='last').head(10)
# Out:
#              full_name educational_level  annual_income
# 2       Alagesan Agate        Graduation        71613.0
# 5  Aprativirya Agrawal            Master        62000.0
# 4      Amrish Aggarwal               PhD        58293.0
# 0        Aditi Acharya        Graduation        58138.0
# 6  Asvathama Ahluwalia        Graduation        55635.0
# 1     Advitiya Agarwal        Graduation        46344.0
# 8        Avantas Ahuja               PhD        30351.0
# 3                  NaN               NaN            NaN
# 7                  NaN               NaN            NaN
# 9                  NaN               NaN            NaN

# %% [markdown]
# Although we don't have exact birthdate of an customer but let's try to find age of the customer from birth year.
#
# Hint: Use `date.today().year` to get year from today's date.

# %%
# Find out the age of customers based on the current year

today = date.today()
year = int(today.year)
df['age'] = year - df['year_of_birth']
df['age']
# Out:
# 0      40.0
# 1      72.0
# 2      57.0
# 3       NaN
# 4      41.0
#        ...
# 495    78.0
# 496    60.0
# 497    44.0
# 498    51.0
# 499    73.0
# Name: age, Length: 500, dtype: float64

# %% [markdown]
# Let's find out the average age and annual income of the customers whoes martial status is either 'Widowed' or 'Divorced'. Based on the data special scheme can be planned for them.

# %%
## Filter the data of Widowed and Divorced martial status and find out their average age and annual income using mean function

df.loc[df['marital_status'].isin(['Widowed', 'Divorced'])][['age', 'annual_income']].mean()
# Out:
# age                 43.467213
# annual_income    51446.631268
# dtype: float64

# %% [markdown]
# Filter the number of customers with an income higher than 75,000 and with a master’s degree.

# %%
# Filter the number of customers with an income higher than 75,000 and with a master’s degree using loc function

df.loc[(df.annual_income > 75000) & (df.educational_level == 'Master')]
# Out:
#      customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 18      20201719     3/28/2013       91                11                9
# 51      20201752    08-11-2012        2                 6               13
# 60      20201761    07-04-2013       12                 3               11
# 76      20201777     8/27/2012       34                 7                5
# 120     20201821     6/20/2013       65                 6               10
# 140     20201841    10/19/2012       46                 5               12
# 217     20201918    11/15/2013       81                 8                6
# 424     20202124    06-04-2013       26                 3                8
# 436     20202136     6/21/2013       49                 1                3
#
#      complaints  calls  intercoms     cust_id  year_of_birth  \
# 18            4      3         11  20201719.0         1980.0
# 51            0      3         11  20201752.0         1964.0
# 60            0      3         11  20201761.0         1982.0
# 76            0      3         11  20201777.0         1993.0
# 120           0      5         11  20201821.0         1957.0
# 140           0      3          2  20201841.0         1987.0
# 217           0      3         11  20201918.0         1985.0
# 424           0      3         11  20202124.0         1973.0
# 436           0      0         11  20202136.0         1983.0
#
#     educational_status_code marital_status  annual_income          full_name  \
# 18                       MS         Single        76995.0      Hardeep Atwal
# 51                       MS         Single        79143.0       Agrata Banik
# 60                       MS         Single        75777.0        Akhil Bassi
# 76                       MS        Married        75251.0      Amithi Bhagat
# 120                      MS   Relationship        88193.0         Deven Chad
# 140                      MS         Single        92859.0  Divya Subramaniam
# 217                      MS        Widowed        83790.0        Ishan Lalla
# 424                      MS   Relationship        82584.0   Premala Randhawa
# 436                      MS   Relationship        82634.0       Rachna Raval
#
#     educational_level   age
# 18             Master  42.0
# 51             Master  58.0
# 60             Master  40.0
# 76             Master  29.0
# 120            Master  65.0
# 140            Master  35.0
# 217            Master  37.0
# 424            Master  49.0
# 436            Master  39.0

# %%
## Extend the previous code to count the number of records i.e customer_id

df.loc[(df.annual_income > 75000) & (df.educational_level == 'Master'), "customer_id"].count()
# Out:
# 9

# %% [markdown]
# We can combine iloc with a python operator to perform the same operation.

# %%
df.iloc[list((df.annual_income > 75000) & (df.educational_level == 'Master')), :]
# Out:
#      customer_id purhcase_date  recency  online_purchases  store_purchases  \
# 18      20201719     3/28/2013       91                11                9
# 51      20201752    08-11-2012        2                 6               13
# 60      20201761    07-04-2013       12                 3               11
# 76      20201777     8/27/2012       34                 7                5
# 120     20201821     6/20/2013       65                 6               10
# 140     20201841    10/19/2012       46                 5               12
# 217     20201918    11/15/2013       81                 8                6
# 424     20202124    06-04-2013       26                 3                8
# 436     20202136     6/21/2013       49                 1                3
#
#      complaints  calls  intercoms     cust_id  year_of_birth  \
# 18            4      3         11  20201719.0         1980.0
# 51            0      3         11  20201752.0         1964.0
# 60            0      3         11  20201761.0         1982.0
# 76            0      3         11  20201777.0         1993.0
# 120           0      5         11  20201821.0         1957.0
# 140           0      3          2  20201841.0         1987.0
# 217           0      3         11  20201918.0         1985.0
# 424           0      3         11  20202124.0         1973.0
# 436           0      0         11  20202136.0         1983.0
#
#     educational_status_code marital_status  annual_income          full_name  \
# 18                       MS         Single        76995.0      Hardeep Atwal
# 51                       MS         Single        79143.0       Agrata Banik
# 60                       MS         Single        75777.0        Akhil Bassi
# 76                       MS        Married        75251.0      Amithi Bhagat
# 120                      MS   Relationship        88193.0         Deven Chad
# 140                      MS         Single        92859.0  Divya Subramaniam
# 217                      MS        Widowed        83790.0        Ishan Lalla
# 424                      MS   Relationship        82584.0   Premala Randhawa
# 436                      MS   Relationship        82634.0       Rachna Raval
#
#     educational_level   age
# 18             Master  42.0
# 51             Master  58.0
# 60             Master  40.0
# 76             Master  29.0
# 120            Master  65.0
# 140            Master  35.0
# 217            Master  37.0
# 424            Master  49.0
# 436            Master  39.0

# %%
# Create a new variable which is the sum of all purchases performed by customers

df['total_purchases'] = df.online_purchases + df.store_purchases
df['total_purchases']
# Out:
# 0      12
# 1       3
# 2      18
# 3       6
# 4      11
#        ..
# 495    15
# 496    16
# 497     5
# 498     8
# 499    17
# Name: total_purchases, Length: 500, dtype: int64

# %% [markdown]
# Find the maximum and minimum annual income of the customer.

# %%
## Find the maximum and minimum annual income of the customer using aggregation function

print(df['annual_income'].max())
print(df['annual_income'].min())
# Out:
# 102692.0
# 2447.0

# %%
## Write an function to segregate annual income as per following
## Greater than 100000: High
## 50000< Salary < 100000: Medium
## Anything below 50000: Low

def income_category(annual_income) :
  if (annual_income >= 100000) :
    return 'High'
  elif (50000 < annual_income < 100000) :
    return 'Medium'
  else :
    return 'Low'

# %%
# Create an income category (low, medium, high) based on the income variable using apply and lambda function

df['income_category'] = df.apply(lambda x: income_category(x["annual_income"]), axis=1) #assign the categories based on income
df[['annual_income', 'income_category']]
# Out:
#      annual_income income_category
# 0          58138.0          Medium
# 1          46344.0             Low
# 2          71613.0          Medium
# 3              NaN             Low
# 4          58293.0          Medium
# ..             ...             ...
# 495        55614.0          Medium
# 496        59432.0          Medium
# 497        55563.0          Medium
# 498        43624.0             Low
# 499        41461.0             Low
#
# [500 rows x 2 columns]

# %% [markdown]
# Find out the number of customer belong to each income category.

# %%
## Find out the number of customer belong to each income category using group by

df.groupby("income_category").count()["customer_id"]
# Out:
# income_category
# High        3
# Low       295
# Medium    202
# Name: customer_id, dtype: int64

# %% [markdown]
# We see very few customer who are in high income category. Display their name, annual income, education status and age.

# %%
## Display their name, annual income, education status and age using normal filtering

df[df["income_category"] == "High"][["full_name",	"educational_level",	"age",	"total_purchases"]]
# Out:
#        full_name educational_level   age  total_purchases
# 124  Devi Chadha        Graduation  65.0               19
# 203  Himani Vyas               PhD  33.0               17
# 252    Jute Mani        Graduation  25.0               19

# %% [markdown]
# Also, we see that we have more customers from low income category then medium income category. It will interesting to find the purchase pattern of both types of customer based on their income, age.

# %%
## Find out the list of columns of merged Dataframe
df.columns
# Out:
# Index(['customer_id', 'purhcase_date', 'recency', 'online_purchases',
#        'store_purchases', 'complaints', 'calls', 'intercoms', 'cust_id',
#        'year_of_birth', 'educational_status_code', 'marital_status',
#        'annual_income', 'full_name', 'educational_level', 'age',
#        'total_purchases', 'income_category'],
#       dtype='object')

# %%
#apply groupby to find the mean of income, recency, number of web and store purchases by educational group
aggregate_view = pd.DataFrame(df.groupby(by='educational_level')[['annual_income', 'recency', 'store_purchases',  'online_purchases']].mean()).reset_index()
aggregate_view.sort_values(by = ['recency'], ascending = False)
# Out:
#   educational_level  annual_income    recency  store_purchases  \
# 2       High School   43883.508193  56.500000         4.607143
# 0             Basic   18058.833333  49.166667         2.833333
# 4               PhD   55086.583107  48.925000         6.537500
# 1        Graduation   51478.705996  46.938462         5.912821
# 3            Master   52145.037977  45.296296         5.981481
#
#    online_purchases
# 2          3.357143
# 0          1.500000
# 4          4.637500
# 1          3.856410
# 3          4.240741

# %% [markdown]
# Does educational level and martial status has any correlation with recency? Find out.

# %%
df_1 = df[['marital_status','educational_level','recency', 'total_purchases']].set_index(['marital_status','educational_level'])
df_1
# Out:
#                                   recency  total_purchases
# marital_status educational_level
# Single         Graduation              58               12
# Married        Graduation              38                3
# Divorced       Graduation              26               18
# NaN            NaN                     26                6
# Widowed        PhD                     94               11
# ...                                   ...              ...
# Divorced       PhD                     85               15
#                Master                  88               16
#                Graduation              22                5
# Relationship   PhD                     83                8
#                PhD                     63               17
#
# [500 rows x 2 columns]

# %%
df_1.groupby(level=['marital_status','educational_level'])['recency'].mean()
# Out:
# marital_status  educational_level
# Divorced        Basic                62.500000
#                 Graduation           52.027778
#                 High School          87.500000
#                 Master               59.800000
#                 PhD                  40.352941
# Married         Graduation           41.590909
#                 High School          67.000000
#                 Master               45.600000
#                 PhD                  65.000000
# Relationship    Basic                39.333333
#                 Graduation           49.641026
#                 High School          44.909091
#                 Master               32.300000
#                 PhD                  41.736842
# Single          Basic                52.000000
#                 Graduation           45.117647
#                 High School          51.500000
#                 Master               50.583333
#                 PhD                  49.250000
# Widowed         Graduation           48.520000
#                 High School          52.000000
#                 Master               33.428571
#                 PhD                  48.142857
# Name: recency, dtype: float64

# %%
grp_1 = df_1.groupby(level=['marital_status','educational_level'])['recency'].agg([np.mean, np.max, np.min]).reset_index()
#grp_1.columns
grp_1.sort_values(by=['amax', 'amin'], ascending=False)
# Out:
#    marital_status educational_level       mean  amax  amin
# 2        Divorced       High School  87.500000    99    76
# 19        Widowed        Graduation  48.520000    99     4
# 1        Divorced        Graduation  52.027778    99     3
# 15         Single        Graduation  45.117647    99     2
# 8         Married               PhD  65.000000    98    17
# 5         Married        Graduation  41.590909    97     1
# 6         Married       High School  67.000000    96     0
# 10   Relationship        Graduation  49.641026    96     0
# 13   Relationship               PhD  41.736842    96     0
# 0        Divorced             Basic  62.500000    94    31
# 22        Widowed               PhD  48.142857    94     1
# 16         Single       High School  51.500000    93    25
# 11   Relationship       High School  44.909091    92     2
# 3        Divorced            Master  59.800000    92     0
# 17         Single            Master  50.583333    91     1
# 18         Single               PhD  49.250000    90     6
# 4        Divorced               PhD  40.352941    88     3
# 12   Relationship            Master  32.300000    87     4
# 7         Married            Master  45.600000    85     4
# 21        Widowed            Master  33.428571    81    12
# 20        Widowed       High School  52.000000    80    24
# 9    Relationship             Basic  39.333333    59    13
# 14         Single             Basic  52.000000    52    52

# %% [markdown]
# Customer with High School and Divorced status has very good recency.

# %% [markdown]
# Now, let's compare get average relevancy and gross total_purchases.

# %%
grp_2 = df_1.groupby(level=['marital_status','educational_level']).agg({'recency' : 'mean', 'total_purchases' : 'sum'})
grp_2.sort_values(by=['total_purchases'], ascending=False)
# Out:
#                                     recency  total_purchases
# marital_status educational_level
# Single         Graduation         45.117647              523
# Married        Graduation         41.590909              421
# Divorced       Graduation         52.027778              367
# Relationship   Graduation         49.641026              346
#                PhD                41.736842              250
# Widowed        Graduation         48.520000              248
# Divorced       PhD                40.352941              194
# Married        PhD                65.000000              182
# Widowed        PhD                48.142857              149
# Married        Master             45.600000              142
# Single         Master             50.583333              135
#                PhD                49.250000              119
# Divorced       Master             59.800000              111
# Relationship   Master             32.300000               99
#                High School        44.909091               90
# Married        High School        67.000000               68
# Widowed        Master             33.428571               65
# Single         High School        51.500000               45
# Relationship   Basic              39.333333               15
# Divorced       High School        87.500000               10
# Widowed        High School        52.000000               10
# Divorced       Basic              62.500000                8
# Single         Basic              52.000000                3

# %%
# Apply pivot table to find the aggregated sum of purchases and mean of recency per education and marital status group
pivot_table = pd.DataFrame(pd.pivot_table(df, values=['total_purchases', 'recency'], index=['marital_status'],
                        columns=['educational_level'], aggfunc={'recency': np.mean, 'total_purchases': np.sum}, fill_value=0)).reset_index()
pivot_table
# Out:
#                   marital_status    recency                                    \
# educational_level                     Basic Graduation High School     Master
# 0                       Divorced  62.500000  52.027778   87.500000  59.800000
# 1                        Married   0.000000  41.590909   67.000000  45.600000
# 2                   Relationship  39.333333  49.641026   44.909091  32.300000
# 3                         Single  52.000000  45.117647   51.500000  50.583333
# 4                        Widowed   0.000000  48.520000   52.000000  33.428571
#
#                              total_purchases                                \
# educational_level        PhD           Basic Graduation High School Master
# 0                  40.352941               8        367          10    111
# 1                  65.000000               0        421          68    142
# 2                  41.736842              15        346          90     99
# 3                  49.250000               3        523          45    135
# 4                  48.142857               0        248          10     65
#
#
# educational_level  PhD
# 0                  194
# 1                  182
# 2                  250
# 3                  119
# 4                  149

# %% [markdown]
# ### Recommendations
# Now after we completed the process of data cleaning and performing operations and aggregations on our dataset, we can conclude with some interesting insights about our customer base:
#
# PhD people have the highest income, number of online and store purchases; however, High School graduates people have the highest recency or number of days since their last purchase.
#
# Basic people account for the lowest number of web and store purchases.
# Married people with Graduation level have the highest total purchases.
# Therefore, the business recommendations for any potential marketing campaign should focus on attracting and retaining PhD people and married couples with Graduation level, and more products should be offered to satisfy the needs and interests of other categories such as Basic people that have the lowest purchases as well as High School people who are not purchasing regularly.
#
# Additionally, further work should be conducted to understand customer behaviors and interests, for example, performing RFM analysis or regression modeling will be beneficial to study the effect of variables on the number of purchases by educational or marital status group.
